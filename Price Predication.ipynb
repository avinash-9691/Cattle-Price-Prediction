# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
pd.pandas.set_option('display.max_columns',None)

# %%
df = pd.read_excel("/content/drive/MyDrive/Price Prediction/animal.xlsx")

# %%
df.head()
# Out:
#    Species       Breed  Gender  Cattle_dob  Total_lactation Current_Lactation  \
# 0      Cow    HF Cross  Female        2019                1               Dry
# 1  Buffalo      Murrah  Female        2018                2           Milking
# 2  Buffalo      Murrah  Female        2018                2               Dry
# 3      Cow    HF Cross  Female        2019                1           Milking
# 4  Buffalo  Desi Cross  Female        2018                1               Dry
#
#    Milk Litre  Price
# 0          24  75000
# 1           8  85000
# 2           8  85000
# 3           7  27000
# 4          10  45000

# %%
df["Cattle_dob"] = df["Cattle_dob"].astype(int)

# %%
#from datetime import datetime

#date_string = '2011-11-21'
#date_object = datetime.strptime(date_string, '%Y-%m-%d')

# %%
#x=df[['Species','Breed','Gender','Cattle_dob','Total_lactation','Current_Lactation']]

# %%
x = df.drop(columns=['Price',])
x
# Out:
#      Species       Breed  Gender  Cattle_dob  Total_lactation  \
# 0        Cow    HF Cross  Female        2019                1
# 1    Buffalo      Murrah  Female        2018                2
# 2    Buffalo      Murrah  Female        2018                2
# 3        Cow    HF Cross  Female        2019                1
# 4    Buffalo  Desi Cross  Female        2018                1
# ..       ...         ...     ...         ...              ...
# 214      Cow  Desi Cross  Female        2018                2
# 215      Cow    HF Cross  Female        2020                1
# 216  Buffalo  Desi Cross  Female        2017                2
# 217      Cow    HF Cross  Female        2017                3
# 218  Buffalo  Desi Cross  Female        2017                2
#
#     Current_Lactation  Milk Litre
# 0                 Dry          24
# 1             Milking           8
# 2                 Dry           8
# 3             Milking           7
# 4                 Dry          10
# ...

# %%
y=df['Price']
y
# Out:
# 0      75000
# 1      85000
# 2      85000
# 3      27000
# 4      45000
#        ...
# 214    50000
# 215    40000
# 216    90000
# 217    25000
# 218    90000
# Name: Price, Length: 219, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
ohe=OneHotEncoder()
ohe.fit(x[['Species','Breed','Gender','Current_Lactation']])
# Out:
# OneHotEncoder()

# %%
#ohe=OneHotEncoder()
#ohe.fit(x[['species','breed','gender','current_lactation']])

# %%
#column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['species','breed','gender','current_lactation']),
 #                                   remainder='passthrough')

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Species','Breed','Gender','Current_Lactation']),
                                    remainder='passthrough')

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(categories=[array(['Buffalo', 'Bull', 'Cow', 'Cow ', 'Male Buffalo'], dtype=object),
#                                                            array(['Deoni', 'Desi Cross', 'Gir', 'HF Cross', 'Jersey Cross', 'Murrah',
#        'Pandharpuri', 'Sahiwal Cross'], dtype=object),
#                                                            array(['Female', 'Male'], dtype=object),
#                                                            array(['Dry', 'Milking', 'Milking '], dtype=object)]),
#                                  ['Species', 'Breed', 'Gender',
#                                   'Current_Lactation'])])

# %%
x
# Out:
#      Species       Breed  Gender  Cattle_dob  Total_lactation  \
# 0        Cow    HF Cross  Female        2019                1
# 1    Buffalo      Murrah  Female        2018                2
# 2    Buffalo      Murrah  Female        2018                2
# 3        Cow    HF Cross  Female        2019                1
# 4    Buffalo  Desi Cross  Female        2018                1
# ..       ...         ...     ...         ...              ...
# 214      Cow  Desi Cross  Female        2018                2
# 215      Cow    HF Cross  Female        2020                1
# 216  Buffalo  Desi Cross  Female        2017                2
# 217      Cow    HF Cross  Female        2017                3
# 218  Buffalo  Desi Cross  Female        2017                2
#
#     Current_Lactation  Milk Litre
# 0                 Dry          24
# 1             Milking           8
# 2                 Dry           8
# 3             Milking           7
# 4                 Dry          10
# ...

# %%
lr=LinearRegression()

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Buffalo', 'Bull', 'Cow', 'Cow ', 'Male Buffalo'], dtype=object),
#                                                                             array(['Deoni', 'Desi Cross', 'Gir', 'HF Cross', 'Jersey Cross', 'Murrah',
#        'Pandharpuri', 'Sahiwal Cross'], dtype=object),
#                                                                             array(['Female', 'Male'], dtype=object),
#                                                                             array(['Dry', 'Milking', 'Milking '], dtype=object)]),
#                                                   ['Species', 'Breed', 'Gender',
#                                                    'Current_Lactation'])])),
# ...

# %%
y_pred=pipe.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6274541602151948

# %%
scores=[]
for i in range(1000):
    X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 896

# %%
scores[np.argmax(scores)]
# Out:
# 0.8705337852679186

# %%
pipe.predict(pd.DataFrame(columns=X_test.columns,data=np.array(['Buffalo','Murrah','Female',2020,2,'Milking','10']).reshape(1,7)))
# Out:
# array([68928.49989422])
